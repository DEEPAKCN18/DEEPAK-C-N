# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPAKCN18/DEEPAK-C-N/blob/main/BASIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df.head(10)
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0           1       Prof          B             19           18    Male  139750
# 1           2       Prof          B             20           16    Male  173200
# 2           3   AsstProf          B              4            3    Male   79750
# 3           4       Prof          B             45           39    Male  115000
# 4           5       Prof          B             40           41    Male  141500
# 5           6  AssocProf          B              6            6    Male   97000
# 6           7       Prof          B             30           23    Male  175000
# 7           8       Prof          B             45           45    Male  147765
# 8           9       Prof          B             21           20    Male  119250
# 9          10       Prof          B             18           18  Female  129000

# %%
df.head(50)
# Out:
#     Unnamed: 0       rank discipline  ...  yrs.service     sex  salary
# 0            1       Prof          B  ...           18    Male  139750
# 1            2       Prof          B  ...           16    Male  173200
# 2            3   AsstProf          B  ...            3    Male   79750
# 3            4       Prof          B  ...           39    Male  115000
# 4            5       Prof          B  ...           41    Male  141500
# 5            6  AssocProf          B  ...            6    Male   97000
# 6            7       Prof          B  ...           23    Male  175000
# 7            8       Prof          B  ...           45    Male  147765
# 8            9       Prof          B  ...           20    Male  119250
# 9           10       Prof          B  ...           18  Female  129000
# 10          11  AssocProf          B  ...            8    Male  119800
# 11          12   AsstProf          B  ...            2    Male   79800
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
total_rows = df.count

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=397, step=1),
#  Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#         'sex', 'salary'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (397, 7)

# %%
df.size
# Out:
# 2779

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %% [markdown]
# ### METHODS

# %%
df.head(10),df.tail(10)
# Out:
# (   Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  salary
#  0           1       Prof          B             19           18    Male  139750
#  1           2       Prof          B             20           16    Male  173200
#  2           3   AsstProf          B              4            3    Male   79750
#  3           4       Prof          B             45           39    Male  115000
#  4           5       Prof          B             40           41    Male  141500
#  5           6  AssocProf          B              6            6    Male   97000
#  6           7       Prof          B             30           23    Male  175000
#  7           8       Prof          B             45           45    Male  147765
#  8           9       Prof          B             21           20    Male  119250
#  9          10       Prof          B             18           18  Female  129000,
#       Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df.std()
# Out:
# Unnamed: 0         114.748275
# yrs.since.phd       12.887003
# yrs.service         13.006024
# salary           30289.038695
# dtype: float64

# %%
df.mean()
# Out:
# Unnamed: 0          199.000000
# yrs.since.phd        22.314861
# yrs.service          17.614610
# salary           113706.458438
# dtype: float64

# %%
df.head(50).mean()
# Out:
# Unnamed: 0           25.50
# yrs.since.phd        20.92
# yrs.service          16.22
# salary           112625.64
# dtype: float64

# %%
import pandas as pd

# %%
df=pd.read_csv("/Salaries.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df['yrs.since.phd']
# Out:
# 0      19
# 1      20
# 2       4
# 3      45
# 4      40
#        ..
# 392    33
# 393    31
# 394    42
# 395    25
# 396     8
# Name: yrs.since.phd, Length: 397, dtype: int64

# %%
df_sub=df[["yrs.since.phd"]]

# %%
df_sub.describe()
# Out:
#        yrs.since.phd
# count     397.000000
# mean       22.314861
# std        12.887003
# min         1.000000
# 25%        12.000000
# 50%        21.000000
# 75%        32.000000
# max        56.000000

# %%
df_sub.size
# Out:
# 397

# %%
df_sub.mean()
# Out:
# yrs.since.phd    22.314861
# dtype: float64

# %%
df['yrs.since.phd'].count()
# Out:
# 397

# %%
df['yrs.since.phd'].mean()
# Out:
# 22.31486146095718

# %%
 df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df_rank=df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
df.groupby('rank')[['salary',yrs.service]].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-eb0055b66039> in <module>()
# ----> 1 df.groupby('rank')[['salary',yrs.service]].mean()
#
# NameError: name 'yrs' is not defined

# %%
df[df['yrs.since.phd']>=20]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 1             2  Prof          B             20           16  Male  173200
# 3             4  Prof          B             45           39  Male  115000
# 4             5  Prof          B             40           41  Male  141500
# 6             7  Prof          B             30           23  Male  175000
# 7             8  Prof          B             45           45  Male  147765
# ..          ...   ...        ...            ...          ...   ...     ...
# 391         392  Prof          A             30           19  Male  151292
# 392         393  Prof          A             33           30  Male  103106
# 393         394  Prof          A             31           19  Male  150564
# 394         395  Prof          A             42           25  Male  101738
# 395         396  Prof          A             25           15  Male   95329
#
# [217 rows x 7 columns]

# %%
df_phd=df[df['yrs.since.phd']>=20]

# %%
df_phd['yrs.since.phd']>=20
# Out:
# 1      True
# 3      True
# 4      True
# 6      True
# 7      True
#        ...
# 391    True
# 392    True
# 393    True
# 394    True
# 395    True
# Name: yrs.since.phd, Length: 217, dtype: bool

# %%
df_phd(df_phd['yrs.since.phd']>=20)(df_phd_['discipline']==A])
# Out:
#   File "<ipython-input-40-a46970de0de3>", line 1
#     df_phd(df_phd['yrs.since.phd']>=20)(df_phd_['discipline']==A])
#                                                                 ^
# SyntaxError: invalid syntax

# %%
df['yrs.since.phd']>=20
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 392     True
# 393     True
# 394     True
# 395     True
# 396    False
# Name: yrs.since.phd, Length: 397, dtype: bool

# %%
(df['discipline']=="A")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 392     True
# 393     True
# 394     True
# 395     True
# 396     True
# Name: discipline, Length: 397, dtype: bool

# %%
(df['yrs.since.phd']>=20)&(df['discipline']=="A")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 392     True
# 393     True
# 394     True
# 395     True
# 396    False
# Length: 397, dtype: bool

# %%
df[(df['yrs.since.phd']>=20)&(df['discipline']=="A")]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service     sex  salary
# 17           18  Prof          A             38           34    Male  103450
# 18           19  Prof          A             37           23    Male  124750
# 19           20  Prof          A             39           36  Female  137000
# 20           21  Prof          A             31           26    Male   89565
# 21           22  Prof          A             36           31    Male  102580
# ..          ...   ...        ...            ...          ...     ...     ...
# 391         392  Prof          A             30           19    Male  151292
# 392         393  Prof          A             33           30    Male  103106
# 393         394  Prof          A             31           19    Male  150564
# 394         395  Prof          A             42           25    Male  101738
# 395         396  Prof          A             25           15    Male   95329
#
# [117 rows x 7 columns]

# %%
df.iloc[0:50]
# Out:
#     Unnamed: 0       rank discipline  ...  yrs.service     sex  salary
# 0            1       Prof          B  ...           18    Male  139750
# 1            2       Prof          B  ...           16    Male  173200
# 2            3   AsstProf          B  ...            3    Male   79750
# 3            4       Prof          B  ...           39    Male  115000
# 4            5       Prof          B  ...           41    Male  141500
# 5            6  AssocProf          B  ...            6    Male   97000
# 6            7       Prof          B  ...           23    Male  175000
# 7            8       Prof          B  ...           45    Male  147765
# 8            9       Prof          B  ...           20    Male  119250
# 9           10       Prof          B  ...           18  Female  129000
# 10          11  AssocProf          B  ...            8    Male  119800
# 11          12   AsstProf          B  ...            2    Male   79800
# ...

# %%
df.iloc[:,3:7]
# Out:
#      yrs.since.phd  yrs.service   sex  salary
# 0               19           18  Male  139750
# 1               20           16  Male  173200
# 2                4            3  Male   79750
# 3               45           39  Male  115000
# 4               40           41  Male  141500
# ..             ...          ...   ...     ...
# 392             33           30  Male  103106
# 393             31           19  Male  150564
# 394             42           25  Male  101738
# 395             25           15  Male   95329
# 396              8            4  Male   81035
#
# [397 rows x 4 columns]

# %%
df.iloc[0:50],df.iloc[:,3:7]
# Out:
# (    Unnamed: 0       rank discipline  ...  yrs.service     sex  salary
#  0            1       Prof          B  ...           18    Male  139750
#  1            2       Prof          B  ...           16    Male  173200
#  2            3   AsstProf          B  ...            3    Male   79750
#  3            4       Prof          B  ...           39    Male  115000
#  4            5       Prof          B  ...           41    Male  141500
#  5            6  AssocProf          B  ...            6    Male   97000
#  6            7       Prof          B  ...           23    Male  175000
#  7            8       Prof          B  ...           45    Male  147765
#  8            9       Prof          B  ...           20    Male  119250
#  9           10       Prof          B  ...           18  Female  129000
#  10          11  AssocProf          B  ...            8    Male  119800
#  11          12   AsstProf          B  ...            2    Male   79800
# ...

# %%
from scipy import stats

# %%
stats.norm.cdf(70,loc=60,scale=10)
# Out:
# 0.8413447460685429

# %%
stats.norm.cdf(680,loc=711,scale=29)
# Out:
# 0.14254260383881612

# %%
1-stats.norm.cdf(720,loc=711,scale=29)
# Out:
# 0.37814937265194704

# %%
1-stats.norm.cdf(650,loc=711,scale=29)
# Out:
# 0.982286698892495

# %%
stats.norm.cdf(730,loc=711,scale=29)
# Out:
# 0.7438216233498722

# %%
0.9822-0.7438
# Out:
# 0.23839999999999995

# %%
stats.norm.cdf(730,loc=711,scale=29)-stats.norm.cdf(650,loc=711,scale=29)
# Out:
# 0.7261083222423672

# %%
stats.norm.cdf(730,loc=711,scale=29)-1-stats.norm.cdf(650,loc=711,scale=29)
# Out:
# -0.2738916777576328

# %%
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-947e6b5cca3b> in <module>()
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import datetime
#       4 import time
#       5 import requests
#
# ModuleNotFoundError: No module named 'yfinance'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
start = datetime.datetime(2020,2,1)
end = datetime.datetime(2020,10,11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c8a1dad3b0d1> in <module>()
# ----> 1 start = datetime.datetime(2020,2,1)
#       2 end = datetime.datetime(2020,10,11)
#
# NameError: name 'datetime' is not defined

# %%
import pandas as pd
import numpy as np

# %%
beml_df=pd.read_csv("/content/BEML.csv")

# %%
beml_df[0:5]
# Out:
#          Date    Open     High  ...    Close  Total Trade Quantity  Turnover (Lacs)
# 0  2010-01-04  1121.0  1151.00  ...  1135.60              101651.0          1157.18
# 1  2010-01-05  1146.8  1149.00  ...  1134.60               59504.0           676.47
# 2  2010-01-06  1140.0  1164.25  ...  1139.60              128908.0          1482.84
# 3  2010-01-07  1142.0  1159.40  ...  1144.15              117871.0          1352.98
# 4  2010-01-08  1156.0  1172.00  ...  1144.05              170063.0          1971.42
#
# [5 rows x 8 columns]

# %%
glaxo_df=pd.read_csv("/content/GLAXO.csv")
glaxo_df[0:5]
# Out:
#          Date     Open     High  ...    Close  Total Trade Quantity  Turnover (Lacs)
# 0  2010-01-04  1613.00  1629.10  ...  1625.65                9365.0           151.74
# 1  2010-01-05  1639.95  1639.95  ...  1616.80               38148.0           622.58
# 2  2010-01-06  1618.00  1644.00  ...  1638.50               36519.0           595.09
# 3  2010-01-07  1645.00  1654.00  ...  1648.70               12809.0           211.00
# 4  2010-01-08  1650.00  1650.00  ...  1639.80               28035.0           459.11
#
# [5 rows x 8 columns]
